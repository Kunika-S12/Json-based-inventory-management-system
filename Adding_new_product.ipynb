# %%
Record = {"1001": {"name": "wheat", "category": "cereals", "Price": 46, "Quantity": 50, "Weight": "1kg"}, 
          "1002": {"name": "rice", "category": "cereals", "Price": 52, "Quantity": 30, "Weight": "1kg"}, 
          "1003": {"name": "toor dal", "category": "pulses", "Price": 95, "Quantity": 35, "Weight": "1kg"}, 
          "1004": {"name": "Bread", "category": "Bakery product", "Price": 50, "Quantity": 50, "Weight": "100gm"}, 
          "1005": {"name": "Cup", "category": "Crockery", "Price": 250, "Quantity": 20, "Weight": "6pcs"}, 
          "1006": {"name": "moond dal", "category": "pulses", "Price": 80, "Quantity": 25, "Weight": "1kg"}, 
          "1007": {"name": "pizza sauce", "category": "Fast food", "Price": 100, "Quantity": 25, "Weight": "250gm"}, 
          "1008": {"name": "maggie", "category": "Fast food", "Price": 30, "Quantity": 20, "Weight": "75gm"}, 
          "1009": {"name": "Cofee", "category": "Drink", "Price": 105, "Quantity": 200, "Weight": "75gm"}, 
          "1010": {"name": "macroni", "category": "Fast food", "Price": 150, "Quantity": 25, "Weight": "150gm"}, 
          "1011": {"name": "Dairymilk", "category": "cadburry", "Price": "40", "Quantity": "50", "Weight": "25gm"}, 
          "1012": {"name": "Mayonnaise", "category": "Fast Food", "Price": "230", "Quantity": "60", "Weight": "241gm"},
          "1013": {"name": "tomato sauce", "category": "Fast Food", "Price": "100", "Quantity": "50", "Weight": "150gm"},
          "1014": {"name": "Maggie pasta", "category": "Fast Food", "Price": "40", "Quantity": "40", "Weight": "50gm"}, 
          "1015": {"name": "red chilli sauce", "category": "Fast Food", "Price": "70", "Quantity": "40", "Weight": "100gm"}, 
          "1016": {"name": " Hakka Noodles", "category": "Fast Food", "Price": "60", "Quantity": "50", "Weight": "100gm"}
          "1017": {"name": "good day biscuit", "category": "Snack", "Price": "25", "Quantity": "60", "Weight": "75gm"}, 
          "1018": {"name": "parle marie", "category": "Snack", "Price": "10", "Quantity": "60", "Weight": "50gm"}, 
          "1019": {"name": "Bourbon biscuit", "category": "snack", "Price": "25", "Quantity": "60", "Weight": "50gm"}, 
          "1020": {"name": "oreo", "category": "snacks", "Price": "30", "Quantity": "60", "Weight": "250gm"},
          "1021": {"name": "Cold cofee", "category": "Drink", "Price": "40", "Quantity": "100", "Weight": "40gm"}, 
          "1022": {"name": "Milk shake", "category": "cold drink", "Price": "40", "Quantity": "60", "Weight": "50gm"}, 
          "1023": {"name": "Fanta", "category": "cold drink", "Price": "50", "Quantity": "90", "Weight": "1ltr"}, 
          "1024": {"name": "Thumbs up", "category": "cold drink", "Price": "70", "Quantity": "70", "Weight": "1ltr"},
          "1025": {"name": "Sprite", "category": "cold drink", "Price": "50", "Quantity": "60", "Weight": "1ltr"}, 
          "1026": {"name": "Milk", "category": "Drink", "Price": "40", "Quantity": "30", "Weight": "1ltr"}, 
          "1027": {"name": "Tea", "category": "drink", "Price": "10", "Quantity": "50", "Weight": "10gm"}, 
          "1028": {"name": "Vanilla icecream", "category": "Dessert", "Price": "25", "Quantity": "50", "Weight": "20gm"}, 
          "1029": {"name": "Mango icecream", "category": "Dessert", "Price": "30", "Quantity": "50", "Weight": "20gm"}, 
          "1030": {"name": "Butterscotch icecream", "category": "Dessert", "Price": "30", "Quantity": "40", "Weight": "20gm"}}

# %%
import json

# %%
js= json.dumps(Record)

# %%
fd= open("Record.json",'w')
fd.write(js)
fd.close()

# %%
fd= open("Record.json",'r')
r= fd.read()
fd.close()
Record= json.loads(r)

# %%
Record
# Out:
# {'1001': {'Price': 46,
#   'Quantity': 50,
#   'Weight': '1kg',
#   'category': 'cereals',
#   'name': 'wheat'},
#  '1002': {'Price': 52,
#   'Quantity': 30,
#   'Weight': '1kg',
#   'category': 'cereals',
#   'name': 'rice'},
#  '1003': {'Price': 95,
#   'Quantity': 35,
#   'Weight': '1kg',
#   'category': 'pulses',
#   'name': 'toor dal'},
#  '1004': {'Price': 50,
#   'Quantity': 50,
#   'Weight': '100gm',
#   'category': 'Bakery product',
#   'name': 'Bread'},
#  '1005': {'Price': 250,
#   'Quantity': 20,
#   'Weight': '6pcs',
#   'category': 'Crockery',
#   'name': 'Cup'},
#  '1006': {'Price': 80,
#   'Quantity': 25,
#   'Weight': '1kg',
#   'category': 'pulses',
#   'name': 'moond dal'},
#  '1007': {'Price': 100,
#   'Quantity': 25,
#   'Weight': '250gm',
#   'category': 'Fast food',
#   'name': 'pizza sauce'},
#  '1008': {'Price': 30,
#   'Quantity': 20,
#   'Weight': '75gm',
#   'category': 'Fast food',
#   'name': 'maggie'},
#  '1009': {'Price': 105,
#   'Quantity': 200,
# ...

# %% [markdown]
# #Addding New Products

# %%
prod_id = (input("Enter a product id: "))
name= (input("Enter a product name: "))
cg = (input("Enter a product category: "))
pr = (input("Enter a product price: "))
quan = (input("Enter a product Quantity: "))
sz= (input("Enter a product size: "))
Record[prod_id] = {"name": name, "category":cg, "Price":pr, "Quantity":quan, "Weight":sz}

js = json.dumps(Record)

fd= open("Record.json",'w')
fd.write(js)
fd.close()
# Out:
# Enter a product id: 1032
# Enter a product name: wipro LED bulb
# Enter a product category: electric appliances
# Enter a product price: 75
# Enter a product Quantity: 30
# Enter a product size: 7 watt

# %%
Record
# Out:
# {'1001': {'Price': 46,
#   'Quantity': 50,
#   'Weight': '1kg',
#   'category': 'cereals',
#   'name': 'wheat'},
#  '1002': {'Price': 52,
#   'Quantity': 30,
#   'Weight': '1kg',
#   'category': 'cereals',
#   'name': 'rice'},
#  '1003': {'Price': 95,
#   'Quantity': 35,
#   'Weight': '1kg',
#   'category': 'pulses',
#   'name': 'toor dal'},
#  '1004': {'Price': 50,
#   'Quantity': 50,
#   'Weight': '100gm',
#   'category': 'Bakery product',
#   'name': 'Bread'},
#  '1005': {'Price': 250,
#   'Quantity': 20,
#   'Weight': '6pcs',
#   'category': 'Crockery',
#   'name': 'Cup'},
#  '1006': {'Price': 80,
#   'Quantity': 25,
#   'Weight': '1kg',
#   'category': 'pulses',
#   'name': 'moond dal'},
#  '1007': {'Price': 100,
#   'Quantity': 25,
#   'Weight': '250gm',
#   'category': 'Fast food',
#   'name': 'pizza sauce'},
#  '1008': {'Price': 30,
#   'Quantity': 20,
#   'Weight': '75gm',
#   'category': 'Fast food',
#   'name': 'maggie'},
#  '1009': {'Price': 105,
#   'Quantity': 200,
# ...
